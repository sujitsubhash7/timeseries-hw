# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# # Regression Analysis: Seasonal Effects with Sklearn Linear Regression
# In this notebook, you will build a SKLearn linear regression model to predict Yen futures ("settle") returns with *lagged* Yen futures returns.

# %%
# Futures contract on the Yen-dollar exchange rate:
# This is the continuous chain of the futures contracts that are 1 month to expiration
yen_futures = pd.read_csv(
    Path("yen.csv"), index_col="Date", infer_datetime_format=True, parse_dates=True
)
yen_futures.head()
# Out:
#               Open    High     Low    Last  Change  Settle  Volume  \
# Date
# 1976-08-02  3398.0  3401.0  3398.0  3401.0     NaN  3401.0     2.0
# 1976-08-03  3401.0  3401.0  3401.0  3401.0     NaN  3401.0     0.0
# 1976-08-04  3401.0  3401.0  3401.0  3401.0     NaN  3401.0     0.0
# 1976-08-05  3401.0  3401.0  3401.0  3401.0     NaN  3401.0     0.0
# 1976-08-06  3401.0  3401.0  3401.0  3401.0     NaN  3401.0     0.0
#
#             Previous Day Open Interest
# Date
# 1976-08-02                         1.0
# 1976-08-03                         1.0
# 1976-08-04                         1.0
# 1976-08-05                         1.0
# 1976-08-06                         1.0

# %%
# Trim the dataset to begin on January 1st, 1990
yen_futures = yen_futures.loc["1990-01-01":, :]
yen_futures.head()
# Out:
#               Open    High     Low    Last  Change  Settle   Volume  \
# Date
# 1990-01-02  6954.0  6954.0  6835.0  6847.0     NaN  6847.0  48336.0
# 1990-01-03  6877.0  6910.0  6865.0  6887.0     NaN  6887.0  38206.0
# 1990-01-04  6937.0  7030.0  6924.0  7008.0     NaN  7008.0  49649.0
# 1990-01-05  6952.0  6985.0  6942.0  6950.0     NaN  6950.0  29944.0
# 1990-01-08  6936.0  6972.0  6936.0  6959.0     NaN  6959.0  19763.0
#
#             Previous Day Open Interest
# Date
# 1990-01-02                     51473.0
# 1990-01-03                     53860.0
# 1990-01-04                     55699.0
# 1990-01-05                     53111.0
# 1990-01-08                     52072.0

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ### Returns

# %%
# Create a series using "Settle" price percentage returns, drop any nan"s, and check the results:
# (Make sure to multiply the pct_change() results by 100)
# In this case, you may have to replace inf, -inf values with np.nan"s
# YOUR CODE HERE!
returns = yen_futures.Settle.pct_change() * 100
yen_futures['Return'] = yen_futures.Settle.pct_change() * 100
yen_futures.dropna(inplace=True)
yen_futures.tail()
# Out:
#               Open    High     Low    Last  Change  Settle    Volume  \
# Date
# 2019-10-09  9381.0  9391.5  9330.5  9343.5    38.5  9338.0   99153.0
# 2019-10-10  9343.5  9380.5  9293.5  9301.0    34.5  9303.5  159397.0
# 2019-10-11  9308.5  9309.0  9240.0  9267.0    52.5  9251.0  158810.0
# 2019-10-14  9259.0  9292.0  9250.5  9261.0    14.0  9265.0   69457.0
# 2019-10-15  9264.5  9280.0  9216.5  9220.0    43.5  9221.5  108342.0
#
#             Previous Day Open Interest    Return
# Date
# 2019-10-09                    145470.0 -0.410601
# 2019-10-10                    144474.0 -0.369458
# 2019-10-11                    147471.0 -0.564304
# 2019-10-14                    153902.0  0.151335
# 2019-10-15                    151564.0 -0.469509

# %% [markdown]
# ### Lagged Returns

# %%
# Create a lagged return using the shift function
# YOUR CODE HERE!
yen_futures['Lagged_Return'] = yen_futures.Return.shift()
yen_futures.dropna()
yen_futures.tail()
# Out:
#               Open    High     Low    Last  Change  Settle    Volume  \
# Date
# 2019-10-09  9381.0  9391.5  9330.5  9343.5    38.5  9338.0   99153.0
# 2019-10-10  9343.5  9380.5  9293.5  9301.0    34.5  9303.5  159397.0
# 2019-10-11  9308.5  9309.0  9240.0  9267.0    52.5  9251.0  158810.0
# 2019-10-14  9259.0  9292.0  9250.5  9261.0    14.0  9265.0   69457.0
# 2019-10-15  9264.5  9280.0  9216.5  9220.0    43.5  9221.5  108342.0
#
#             Previous Day Open Interest    Return  Lagged_Return
# Date
# 2019-10-09                    145470.0 -0.410601       0.170931
# 2019-10-10                    144474.0 -0.369458      -0.410601
# 2019-10-11                    147471.0 -0.564304      -0.369458
# 2019-10-14                    153902.0  0.151335      -0.564304
# 2019-10-15                    151564.0 -0.469509       0.151335

# %%
yen_futures = yen_futures.loc['2014-02-19':,:]
yen_futures.head()
# Out:
#               Open    High     Low    Last  Change  Settle    Volume  \
# Date
# 2014-02-19  9768.0  9825.0  9760.0  9773.0     2.0  9773.0  129508.0
# 2014-02-20  9774.0  9837.0  9765.0  9775.0     2.0  9775.0  160202.0
# 2014-02-21  9772.0  9776.0  9725.0  9758.0    20.0  9755.0  103091.0
# 2014-02-24  9752.0  9789.0  9740.0  9757.0     2.0  9757.0   90654.0
# 2014-02-25  9760.0  9808.0  9744.0  9789.0    32.0  9789.0  105498.0
#
#             Previous Day Open Interest    Return  Lagged_Return
# Date
# 2014-02-19                    197197.0 -0.020460      -0.427829
# 2014-02-20                    198280.0  0.020465      -0.020460
# 2014-02-21                    202990.0 -0.204604       0.020465
# 2014-02-24                    203114.0  0.020502      -0.204604
# 2014-02-25                    201486.0  0.327970       0.020502

# %% [markdown]
# ### Train Test Split

# %%
# Create a train/test split for the data using 2018-2019 for testing and the rest for training
train = yen_futures[:'2017']
test = yen_futures['2018':]

# %%
# Create four dataframes:
# X_train (training set using just the independent variables), X_test (test set of of just the independent variables)
# Y_train (training set using just the "y" variable, i.e., "Futures Return"), Y_test (test set of just the "y" variable):
# YOUR CODE HERE!
X_train = train["Lagged_Return"].to_frame()
X_test = test["Lagged_Return"].to_frame()
y_train = train["Return"].to_frame()
y_test = test["Return"].to_frame()

# %%
X_train
# Out:
#             Lagged_Return
# Date
# 2014-02-19      -0.427829
# 2014-02-20      -0.020460
# 2014-02-21       0.020465
# 2014-02-24      -0.204604
# 2014-02-25       0.020502
# ...                   ...
# 2017-12-22       0.084621
# 2017-12-26       0.118370
# 2017-12-27       0.118230
# 2017-12-28      -0.151830
# 2017-12-29       0.180221
#
# [966 rows x 1 columns]

# %%
y_train
# Out:
#               Return
# Date
# 2014-02-19 -0.020460
# 2014-02-20  0.020465
# 2014-02-21 -0.204604
# 2014-02-24  0.020502
# 2014-02-25  0.327970
# ...              ...
# 2017-12-22  0.118370
# 2017-12-26  0.118230
# 2017-12-27 -0.151830
# 2017-12-28  0.180221
# 2017-12-29  0.224871
#
# [966 rows x 1 columns]

# %% [markdown]
# # Linear Regression Model

# %%
# Create a Linear Regression model and fit it to the training data
from sklearn.linear_model import LinearRegression
model = LinearRegression()
# Fit a SKLearn linear regression using just the training set (X_train, Y_train):
# YOUR CODE HERE!
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Make predictions using the Testing Data
#
# Note: We want to evaluate the model using data that it has never seen before, in this case: X_test.

# %%
# Make a prediction of "y" values using just the test dataset
# YOUR CODE HERE!
predicted_y = model.predict(X_test)
predicted_y[:5]
predicted_y = pd.DataFrame(predicted_y, columns=['Prediction'])
predicted_y.head()
# Out:
#    Prediction
# 0   -0.008621
# 1   -0.008885
# 2   -0.006923
# 3   -0.007024
# 4   -0.006509

# %%
y_test2 = y_test

# %%
y_test = y_test.reset_index(drop=True)

# %%
y_test.head()
# Out:
#      Return
# 0  0.297285
# 1 -0.240479
# 2 -0.213028
# 3 -0.353933
# 4  0.062017

# %%
# Assemble actual y data (Y_test) with predicted y data (from just above) into two columns in a dataframe:
# YOUR CODE HERE!
df_compare = pd.concat([predicted_y,y_test], axis = 1)
df_compare.head(20)
# Out:
#     Prediction    Return
# 0    -0.008621  0.297285
# 1    -0.008885 -0.240479
# 2    -0.006923 -0.213028
# 3    -0.007024 -0.353933
# 4    -0.006509  0.062017
# 5    -0.008027  0.388776
# 6    -0.009219  1.161812
# 7    -0.012040  0.233023
# 8    -0.008651  0.016606
# 9    -0.007861  0.675190
# 10   -0.010264 -0.731131
# 11   -0.005133  0.088603
# 12   -0.008124  0.354100
# 13   -0.009093 -0.363877
# 14   -0.006473  0.603143
# 15   -0.010001  1.160552
# 16   -0.012035 -0.347977
# 17   -0.006531  0.682017
# 18   -0.010289 -0.249282
# 19   -0.006891  0.152116

# %%
y_test2.reset_index(inplace=True)
y_test2.head()
# Out:
#         Date    Return
# 0 2018-01-02  0.297285
# 1 2018-01-03 -0.240479
# 2 2018-01-04 -0.213028
# 3 2018-01-05 -0.353933
# 4 2018-01-08  0.062017

# %%
fig, (ax1, ax2) = plt.subplots(2)
fig.suptitle('Vertically stacked subplots')
ax1.plot(y_test2.Date[:20], df_compare.Prediction[:20])
ax2.plot(y_test2.Date[:20], df_compare.Prediction[:20],'tab:orange')

# %%
df_compare.Return[:20].plot(X = y_test2.Date)
# Out:
# <AxesSubplot:>

# %%
# Plot the first 20 predictions vs the true values
# YOUR CODE HERE!

# Importing libraries
import matplotlib.pyplot as plt

  
# Create X
X = y_test2.Date
  
# Assign variables to the y axis part of the curve
y = df_compare.Return[:20]
z = df_compare.Prediction[:20]
  
# Plotting both the curves simultaneously
plt.plot(X, y, color='b', label='Return')
plt.plot(X, z, color='o', label='Predicted Return')
  
# Naming the x-axis, y-axis and the whole graph
plt.xlabel("Date")
plt.ylabel("Returns")
plt.title("Return vs Predicted Return")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-4d9d4461b6e5> in <module>
#      14
#      15 # Plotting both the curves simultaneously
# ---> 16 plt.plot(X, y, color='b', label='Return')
#      17 plt.plot(X, z, color='o', label='Predicted Return')
#      18
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
# -> 2842         **({"data": data} if data is not None else {}), **kwargs)
#    2843
#    2844
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# ~\Anaconda3\envs\mlenv\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (448,) and (20,)

# %% [markdown]
# # Out-of-Sample Performance
#
# Evaluate the model using "out-of-sample" data (X_test and y_test)

# %%
from sklearn.metrics import mean_squared_error
# Calculate the mean_squared_error (MSE) on actual versus predicted test "y" 
# YOUR CODE HERE!
mse = mean_squared_error(y_test,predicted_y)
print(mse)
# Using that mean-squared-error, calculate the root-mean-squared error (RMSE):
# YOUR CODE HERE!
rmse = np.sqrt(mse)
rmse
# Out:
# 0.17262635470120388
# 0.4154832784856737

# %% [markdown]
# # In-Sample Performance
#
# Evaluate the model using in-sample data (X_train and y_train)

# %%
# Construct a dataframe using just the "y" training data:
# YOUR CODE HERE!
y_train = y_train.reset_index(drop= True)
y_train.head()
# Out:
#      Return
# 0 -0.020460
# 1  0.020465
# 2 -0.204604
# 3  0.020502
# 4  0.327970

# %%
# Add a column of "in-sample" predictions to that dataframe:  
# YOUR CODE HERE!
insample_pred_y = model.predict(X_train)
insample_pred_y = pd.DataFrame(insample_pred_y, columns=['In-Sameple Prediction'])
df = pd.concat([insample_pred_y,y_train], axis = 1)
df.head()
# Out:
#    In-Sameple Prediction    Return
# 0              -0.006240 -0.020460
# 1              -0.007726  0.020465
# 2              -0.007875 -0.204604
# 3              -0.007054  0.020502
# 4              -0.007876  0.327970

# %%
# Calculate in-sample mean_squared_error (for comparison to out-of-sample)
# YOUR CODE HERE!
mse_insample = mean_squared_error(y_train,insample_pred_y)
print(mse_insample)
# Calculate in-sample root mean_squared_error (for comparison to out-of-sample)
# YOUR CODE HERE!
rmse_insample = np.sqrt(mse_insample)
rmse_insample
# Out:
# 0.35565249959422596
# 0.5963660785073426

# %% [markdown]
# # Conclusions

# %% [markdown]
# YOUR CONCLUSIONS HERE!
